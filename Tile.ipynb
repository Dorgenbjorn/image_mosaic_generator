# %%
from functools import reduce

import numpy as np
import pandas as pd
import cv2


class TiledImage:


    image = None
    tile_shape = None
    partitions = None
    color_matrix = None
    

    def __init__(self, image_path, tile_shape=(100, 100), scaling_factor=None):
        """Does the following:
        0. initialize self.image
        1. extract the height and width of the image;
        2. partition the image;
        3. calculate the average color value for each partition;
        4. store these average color values in a parallel matrix;
        """

        image = cv2.imread(image_path)
        self.image = cv2.cvtColor(image, cv2.COLOR_BGR2Lab)
        if scaling_factor is None:
            pass
        else:
            x, y, c = self.image.shape
            self.image = cv2.resize(self.image, (y*scaling_factor, x*scaling_factor), interpolation=cv2.INTER_CUBIC)
        self.tile_shape = tile_shape
        height, width, _  = self.image.shape
        self.partition_matrix = self.partition(height, width)
        self.color_matrix = self.generate_color_matrix(self.partition_matrix)


    def make(self, image_dataframe, unique_flag=False):
        """Does the following:
        0. queries the image dataframe for CIELab color statistics;
        1. make a matrix of the distance between the average color of
            a tile on self.image and the average color of each
            image in the dataframe;
        2. take the argmin of this matrix to get the "best match" for
            and image tile, then replace that "best match" with np.inf (if duplicate images are not allowed)
            repeating the process until every image tile has a match
        3. load each of the selected images, rescale each image to the size of the tile, then
            concatenate each image together to get the resultant image;
        4. return the image.
        """
        
        distance_matrix = []
        for i, row in enumerate(self.color_matrix):
            for j, color in enumerate(row):
                d_L = np.array(image_dataframe["mean_L"] - color[0])**2
                d_a = np.array(image_dataframe["mean_a"] - color[1])**2
                d_b = np.array(image_dataframe["mean_b"] - color[2])**2
                dist = d_L + d_a + d_b
                distance_matrix.append(dist)
                
        distance_matrix = np.array(distance_matrix)
        if unique_flag:
            mapping_matrix = self.gen_unique_mapping_matrix(distance_matrix)
        else:
            mapping_matrix = self.gen_mapping_matrix(distance_matrix)
        image = self.construct_image(mapping_matrix, image_dataframe)
        return image
    
    
    def gen_mapping_matrix(self, distance_matrix):
        
        mapping_matrix = np.full(self.color_matrix.shape[:2], -1, dtype=int)
        mp_n, mp_m = mapping_matrix.shape
        column_vector = np.apply_along_axis(np.argmin, 1, distance_matrix)
        for i, j in enumerate(column_vector):
            mapping_matrix[i//mp_m, i%mp_m] = j
        return mapping_matrix
        
        
    def gen_unique_mapping_matrix(self, distance_matrix):
        
        mapping_matrix = np.full(self.color_matrix.shape[:2], -1, dtype=int)
        mp_n, mp_m = mapping_matrix.shape
        n, m = distance_matrix.shape
        char_array = ["-", "\\", "|", "/"]
        c = 0
        while np.min(mapping_matrix) <= -1:
            k = np.argmin(distance_matrix)
            i, j = k//m, k%m
            val = distance_matrix[i, j]
            if np.isinf(val):
                break
            distance_matrix[:, j] = np.inf
            distance_matrix[i, :] = np.inf
            mapping_matrix[i//mp_m, i%mp_m] = j
            print(char_array[c], end="\r")
            c += 1
            if c >= 4:
                c = 0
        if np.min(mapping_matrix) <= -1:
            print("Not enough images.")
            return None
        return mapping_matrix
    
    
    def construct_image(self, mapping_matrix, image_dataframe):
        
        image_cache = dict()
        read_n_scale = lambda p: cv2.resize(cv2.imread(p), self.tile_shape, interpolation=cv2.INTER_CUBIC)
        tiles = []
        for row in mapping_matrix:
            im_paths = image_dataframe["path"].iloc[row]
            images = []
            for p in im_paths:
                if p in image_cache.keys():
                    images.append(image_cache[p])
                else:
                    im = read_n_scale(p)
                    image_cache.update({p: im})
                    images.append(im)
            tiles.append(images)
        strips = [np.concatenate(row, axis=1) for row in tiles]
        image = np.concatenate(strips, axis=0)
        return image
    

    def partition(self, h, w):
        """Takes height and width of the image as argumens
        (h and w respectively.)
        Returns an nxmx4 numpy array
        where each cell describes the position of 
        the image tile (relative to others), and the channels describe
        the absolute position of the image tile in pixels (we can 
        derrive the shape of the tile from this information.)
        """
        
        a, b = self.tile_shape
        n = int(h/a)
        m = int(w/b)
        partition_matrix = []
        for i in range(n):
            partition_row = []
            i_0 = a*i
            i_n = i_0 + a
            for j in range(m):
                j_0 = b*j
                j_n = j_0 + b
                tile = (slice(i_0, i_n), slice(j_0, j_n))
                partition_row.append(tile)
            partition_matrix.append(partition_row)
        return np.array(partition_matrix)


    def generate_color_matrix(self, partition_matrix):
        
        color_matrix = []
        for row in partition_matrix:
            color_row = []
            for tile in row:
                row_slice, column_slice = tile
                image = self.image[row_slice, column_slice, :]
                mean_color = self.average_colors(image)
                color_row.append(mean_color)
            color_matrix.append(color_row)
        return np.array(color_matrix)


    def average_colors(self, image):
        
        mean_L = image[:, :, 0].mean()
        mean_a = image[:, :, 1].mean()
        mean_b = image[:, :, 2].mean()
        return np.array([mean_L, mean_a, mean_b])

# %%
image_path = "coast.jpg"

# %%
timmy = TiledImage(image_path=image_path, tile_shape=(100,100), scaling_factor=10)

# %%
timmy.image.shape
# Out:
# (12000, 18000, 3)

# %%
# timmy.partition_matrix

# %%
# timmy.color_matrix

# %%
meme_df = pd.read_csv("Meme_Repository.csv")

# %%
dist_matrix = timmy.make(meme_df, unique_flag=False)

# %%
cv2.imwrite("coast_non_unique_20x20.jpg", dist_matrix)
# Out:
# True

# %%
np.argmin(dist_matrix.shape)
# Out:
# 0

# %%
import os
dest_dir = r"Q:\generated_images"
x = 10
y = 10
for path in meme_df["path"]:
    ti = TiledImage(image_path=path, tile_shape=(x, y))
    im = ti.make(meme_df)
    f_name = os.path.basename(path)
    dest_path = os.path.join(dest_dir, f_name)    
    cv2.imwrite(dest_path, im)
    print(dest_path)
# Out:
# Q:\generated_images\0.jpg
# Q:\generated_images\02BzeHE.jpg
# Q:\generated_images\1.jpg
# Q:\generated_images\1.PNG
# Q:\generated_images\1111222223333333.jpg
# Q:\generated_images\1407811233065.jpg
# Q:\generated_images\1407954939271.jpg
# Q:\generated_images\1408867011604.jpg
# Q:\generated_images\1409095063419.png
# Q:\generated_images\1409095874822.jpg
# Q:\generated_images\1409096905256.jpg
# Q:\generated_images\1409097371976.png
# Q:\generated_images\1409195963186.jpg
# Q:\generated_images\1409197964185.jpg
# Q:\generated_images\1409198321147.jpg
# Q:\generated_images\1409465344314.jpg
# Q:\generated_images\1409621388599.jpg
# Q:\generated_images\1409634394133.jpg
# Q:\generated_images\1409634487225.jpg
# Q:\generated_images\1409634524346.jpg
# Q:\generated_images\1409634561960.jpg
# Q:\generated_images\1409634834454.jpg
# Q:\generated_images\1409634880782.jpg
# Q:\generated_images\1409634888510.jpg
# Q:\generated_images\1409635527512.jpg
# Q:\generated_images\1409712026659.jpg
# Q:\generated_images\1409794076563.jpg
# Q:\generated_images\1409794126536.png
# Q:\generated_images\1409794137367.jpg
# Q:\generated_images\1409794148799.jpg
# Q:\generated_images\1409794236861.jpg
# Q:\generated_images\1409794304982.jpg
# Q:\generated_images\1409794380730.jpg
# Q:\generated_images\1409794705696.jpg
# Q:\generated_images\1409794809179.jpg
# Q:\generated_images\1409794874718.jpg
# Q:\generated_images\1409795032671.jpg
# Q:\generated_images\1409795032671profile.jpg
# Q:\generated_images\1409795036046.jpg
# Q:\generated_images\1409795036046profile.jpg
# Q:\generated_images\1409803749578.jpg
# Q:\generated_images\1409803865982.jpg
# Q:\generated_images\1410075201944.jpg
# Q:\generated_images\1410076433376.png
# Q:\generated_images\1410076533363.jpg
# Q:\generated_images\1410214992150.jpg
# Q:\generated_images\1410216317026.jpg
# Q:\generated_images\1410217878162.jpg
# Q:\generated_images\1410218107332.jpg
# Q:\generated_images\1410218160293.jpg
# Q:\generated_images\1410301105159.jpg
# Q:\generated_images\1410301250575.jpg
# Q:\generated_images\1410301321169.jpg
# Q:\generated_images\1410301585129.jpg
# Q:\generated_images\1410301638685.jpg
# Q:\generated_images\1410379326826.jpg
# Q:\generated_images\1410399101954.jpg
# Q:\generated_images\1410429373712.jpg
# Q:\generated_images\1410429697211.jpg
# Q:\generated_images\1410429834583.jpg
# Q:\generated_images\1410429847025.png
# Q:\generated_images\1410430151479.jpg
# Q:\generated_images\1410430501174.png
# Q:\generated_images\1410437780295.jpg
# Q:\generated_images\1410437856061.png
# Q:\generated_images\1410437986154.jpg
# Q:\generated_images\1410438032765.png
# Q:\generated_images\1410438780265.jpg
# Q:\generated_images\1410438977115.jpg
# Q:\generated_images\1410548370089.jpg
# Q:\generated_images\1410549518980.jpg
# Q:\generated_images\1410549884249.jpg
# Q:\generated_images\1410552120465.jpg
# Q:\generated_images\1410554057279.jpg
# Q:\generated_images\1410554744395.jpg
# Q:\generated_images\1410555854684.jpg
# Q:\generated_images\1410675281468.png
# Q:\generated_images\1410675656058.jpg
# Q:\generated_images\1410677450813.jpg
# Q:\generated_images\1410678558671.jpg
# Q:\generated_images\1410702007049.jpg
# Q:\generated_images\1410829906874.jpg
# Q:\generated_images\1410834429868.png
# Q:\generated_images\1410834454475.jpg
# Q:\generated_images\1410834849758.jpg
# Q:\generated_images\1410836649490.jpg
# Q:\generated_images\1410836687258.jpg
# Q:\generated_images\1410836721410.jpg
# Q:\generated_images\1410836754200.jpg
# Q:\generated_images\1410836760106.jpg
# Q:\generated_images\1410836793094.jpg
# Q:\generated_images\1410836839453.jpg
# Q:\generated_images\1410836840666.jpg
# Q:\generated_images\1410836880353.jpg
# Q:\generated_images\1410836915427.jpg
# Q:\generated_images\1410836944379.jpg
# Q:\generated_images\1410836947176.jpg
# Q:\generated_images\1410836976460.jpg
# Q:\generated_images\1410836978005.jpg
# Q:\generated_images\1410837028429.jpg
# Q:\generated_images\1410837060596.jpg
# Q:\generated_images\1410837076873.jpg
# Q:\generated_images\1410837098332.jpg
# Q:\generated_images\1410837755434.jpg
# Q:\generated_images\1411192660273.jpg
# Q:\generated_images\1411193147728.jpg
# Q:\generated_images\1411349746845.jpg
# Q:\generated_images\1411415740489.jpg
# Q:\generated_images\1411433778327.jpg
# Q:\generated_images\1411436244648.jpg
# Q:\generated_images\1411701934628.jpg
# Q:\generated_images\1411960996090.jpg
# Q:\generated_images\1411961667751.jpg
# Q:\generated_images\1411984466091.jpg
# Q:\generated_images\1412120111189.png
# Q:\generated_images\1412125237185.jpg
# Q:\generated_images\1412125239570.jpg
# Q:\generated_images\1412217526626.jpg
# Q:\generated_images\1412219807273.png
# Q:\generated_images\1412308230113.jpg
# Q:\generated_images\1412308295650.jpg
# Q:\generated_images\1412309491499.jpg
# Q:\generated_images\1412431174821.png
# Q:\generated_images\1412431187356.jpg
# Q:\generated_images\1412431272361.jpg
# Q:\generated_images\1412431342978.jpg
# Q:\generated_images\1412432287452.jpg
# Q:\generated_images\1412432292510.jpg
# Q:\generated_images\1412432529158.jpg
# Q:\generated_images\1412432615265.jpg
# Q:\generated_images\1412432656424.jpg
# Q:\generated_images\1412432692417.jpg
# Q:\generated_images\1412432724361.jpg
# Q:\generated_images\1412432729202.jpg
# Q:\generated_images\1412432764492.jpg
# Q:\generated_images\1412432809922.jpg
# Q:\generated_images\1412432861027.jpg
# Q:\generated_images\1412432933749.jpg
# Q:\generated_images\1412570844883.png
# Q:\generated_images\1412803959401.jpg
# Q:\generated_images\1412817324809.jpg
# Q:\generated_images\1413004287877.jpg
# Q:\generated_images\1413006797518.png
# Q:\generated_images\1413007447202.png
# Q:\generated_images\1413008907285.jpg
# Q:\generated_images\1413117120556.jpg
# Q:\generated_images\1413119401233.jpg
# Q:\generated_images\1413119850868s.jpg
# Q:\generated_images\1413119911559.jpg
# Q:\generated_images\1413120118271.png
# Q:\generated_images\1413120766253.png
# Q:\generated_images\1413120853599.png
# Q:\generated_images\1413120916867.jpg
# Q:\generated_images\1413121152571.png
# Q:\generated_images\1413121390260.png
# Q:\generated_images\1413122516230.jpg
# Q:\generated_images\1413122658897.jpg
# Q:\generated_images\1413122689535.jpg
# Q:\generated_images\1413122913484.jpg
# Q:\generated_images\1413122943860.jpg
# Q:\generated_images\1413123065143.jpg
# Q:\generated_images\1413123870704.jpg
# Q:\generated_images\1413123960.jpg
# Q:\generated_images\1413123960301.jpg
# Q:\generated_images\1413124060538.png
# Q:\generated_images\1413187729059.jpg
# Q:\generated_images\1413188182255.jpg
# Q:\generated_images\1413188230612.jpg
# Q:\generated_images\1413190225600.jpg
# Q:\generated_images\1413190495321.png
# Q:\generated_images\1413190527030.png
# Q:\generated_images\1413190596938.jpg
# Q:\generated_images\1413190728034.jpg
# Q:\generated_images\1413190894137.jpg
# Q:\generated_images\1413191078983.jpg
# Q:\generated_images\1413193459122.jpg
# Q:\generated_images\1413193687380.jpg
# Q:\generated_images\1413195947273.jpg
# Q:\generated_images\1413196168810.jpg
# Q:\generated_images\1413196402985.png
# Q:\generated_images\1413196439743.jpg
# Q:\generated_images\1413196762913.jpg
# Q:\generated_images\1413196883710.png
# Q:\generated_images\1413196989854.jpg
# Q:\generated_images\1413197141187.jpg
# Q:\generated_images\1413197818905.jpg
# Q:\generated_images\1413198781778.png
# Q:\generated_images\1413239653694.jpg
# Q:\generated_images\1413240261696.png
# Q:\generated_images\1413327090822.jpg
# Q:\generated_images\1413359591605.png
# Q:\generated_images\1413359604738.jpg
# Q:\generated_images\1413361781630.jpg
# Q:\generated_images\1413362013398.jpg
# Q:\generated_images\1413364376347.jpg
# Q:\generated_images\1413365725610.jpg
# Q:\generated_images\1413370950095.jpg
# Q:\generated_images\1413434322555.png
# Q:\generated_images\1413434631238.png
# Q:\generated_images\1413434732802.jpg
# Q:\generated_images\1413434829635.jpg
# Q:\generated_images\1413434844894.jpg
# Q:\generated_images\1413461273194.jpg
# Q:\generated_images\1413462193340.jpg
# Q:\generated_images\1413633643224.png
# Q:\generated_images\1413633727105.jpg
# Q:\generated_images\1413633838296.jpg
# Q:\generated_images\1413633849999.jpg
# Q:\generated_images\1413633879098.jpg
# Q:\generated_images\1413633910805.jpg
# Q:\generated_images\1413633910805a.jpg
# Q:\generated_images\1413634153526.jpg
# Q:\generated_images\1413634317166.jpg
# Q:\generated_images\14136343171663.jpg
# Q:\generated_images\1413634538515.jpg
# Q:\generated_images\1413634866015.jpg
# Q:\generated_images\1413634968350.jpg
# Q:\generated_images\1413635113020.jpg
# Q:\generated_images\1413635914642.jpg
# Q:\generated_images\1413635957110.jpg
# Q:\generated_images\1413636173573.jpg
# Q:\generated_images\1413636218905.jpg
# Q:\generated_images\1413636573107.png
# Q:\generated_images\1413636768857.jpg
# Q:\generated_images\1413636916721.jpg
# Q:\generated_images\1413637076822.jpg
# Q:\generated_images\1413637410656.jpg
# Q:\generated_images\1413637504444.jpg
# Q:\generated_images\1413637526402.jpg
# Q:\generated_images\1413637625458.jpg
# Q:\generated_images\1413637710069.jpg
# Q:\generated_images\1413637737712.jpg
# Q:\generated_images\1413931640292.jpg
# Q:\generated_images\1413932687579.jpg
# Q:\generated_images\1413951519536.jpg
# Q:\generated_images\1414215023974.jpg
# Q:\generated_images\1414373413088.png
# Q:\generated_images\1414620046463.jpg
# Q:\generated_images\1414950635484.png
# Q:\generated_images\1414951139461.jpg
# Q:\generated_images\1414951271398.jpg
# Q:\generated_images\1414951461684.jpg
# Q:\generated_images\1414951684195.jpg
# Q:\generated_images\1414952268493.jpg
# Q:\generated_images\1416183397473.jpg
# Q:\generated_images\1416183699963.jpg
# Q:\generated_images\1416183805532.jpg
# Q:\generated_images\1416183884671.jpg
# Q:\generated_images\1416183893590.jpg
# Q:\generated_images\1416184146281.jpg
# Q:\generated_images\1416184315717.jpg
# Q:\generated_images\1416184648399.jpg
# Q:\generated_images\1416185911304.jpg
# Q:\generated_images\1416194054162.jpg
# Q:\generated_images\1416195195290.jpg
# Q:\generated_images\1416196149031.jpg
# Q:\generated_images\1416196189197.jpg
# Q:\generated_images\1416266187211.jpg
# Q:\generated_images\1416268319722.jpg
# Q:\generated_images\1416840720265.jpg
# Q:\generated_images\1416841478045.jpg
# Q:\generated_images\1416841615846.png
# Q:\generated_images\1417019995296.png
# Q:\generated_images\1417159571408.png
# Q:\generated_images\1417159625180.png
# Q:\generated_images\1417159687063.png
# Q:\generated_images\1417261424751.jpg
# Q:\generated_images\1417266564289.jpg
# Q:\generated_images\1417329553947.png
# Q:\generated_images\1417329681944.jpg
# Q:\generated_images\1417331283512.jpg
# Q:\generated_images\1417331366932.jpg
# Q:\generated_images\1417332960841.jpg
# Q:\generated_images\1417394749262.png
# Q:\generated_images\1417558965191.jpg
# Q:\generated_images\1417559256133.jpg
# Q:\generated_images\1417559409686.jpg
# Q:\generated_images\1417559428837.jpg
# Q:\generated_images\1417560153657.jpg
# Q:\generated_images\1417560630225.jpg
# Q:\generated_images\1417560833907.jpg
# Q:\generated_images\1417561272968.jpg
# Q:\generated_images\1417562589962.jpg
# Q:\generated_images\1417659823827.jpg
# Q:\generated_images\1417758929123.jpg
# Q:\generated_images\1417759552291.jpg
# Q:\generated_images\1417759569692.png
# Q:\generated_images\1417759790845.jpg
# Q:\generated_images\1417759930673.jpg
# Q:\generated_images\1417760098210.jpg
# Q:\generated_images\1417760203795.png
# Q:\generated_images\1417760243734.jpg
# Q:\generated_images\1417760413889.jpg
# Q:\generated_images\1417760414205.png
# Q:\generated_images\1417760615384.jpg
# Q:\generated_images\1417760781645 (1).png
# Q:\generated_images\1417760781645.png
# Q:\generated_images\1417760942432.jpg
# Q:\generated_images\1417761103119.jpg
# Q:\generated_images\1418015012864.png
# Q:\generated_images\1418172844193.jpg
# Q:\generated_images\1418173011716.jpg
# Q:\generated_images\1418174217959.jpg
# Q:\generated_images\1418175376628.jpg
# Q:\generated_images\1418175450657.jpg
# Q:\generated_images\1418176109671.jpg
# Q:\generated_images\1418176313714.jpg
# Q:\generated_images\1418176433262.jpg
# Q:\generated_images\1418176710428.jpg
# Q:\generated_images\1418176729671.jpg
# Q:\generated_images\1418177223464.jpg
# Q:\generated_images\1418177227307.jpg
# Q:\generated_images\1418305037916.jpg
# Q:\generated_images\1418305268412.jpg
# Q:\generated_images\1418305307988.jpg
# Q:\generated_images\1418305320776.jpg
# Q:\generated_images\1418365871740.jpg
# Q:\generated_images\1418493521624.jpg
# Q:\generated_images\1418495190651.jpg
# Q:\generated_images\1418562115098.jpg
# Q:\generated_images\1418562144911.png
# Q:\generated_images\1418562812248.jpg
# Q:\generated_images\1418562914442.jpg
# Q:\generated_images\1418607389295.jpg
# Q:\generated_images\1418607875917.jpg
# Q:\generated_images\1418647030854.jpg
# Q:\generated_images\1418647672430.jpg
# Q:\generated_images\1418823863978.jpg
# Q:\generated_images\1419024500783.jpg
# Q:\generated_images\1419743216027.png
# Q:\generated_images\1420094664438.png
# Q:\generated_images\1420094665661.jpg
# Q:\generated_images\1420094719892.jpg
# Q:\generated_images\1420094758615.jpg
# Q:\generated_images\1420094775948.png
# Q:\generated_images\1420094776628.jpg
# Q:\generated_images\1420094830333.jpg
# Q:\generated_images\1420094966976.jpg
# Q:\generated_images\1420094982435.jpg
# Q:\generated_images\1420251607647.png
# Q:\generated_images\1420348101214.jpg
# Q:\generated_images\1420349213949.png
# Q:\generated_images\1420349494323.jpg
# Q:\generated_images\1420349647952.jpg
# Q:\generated_images\1420351134495.jpg
# Q:\generated_images\1420750574837.jpg
# Q:\generated_images\1421129353315.jpg
# Q:\generated_images\1421154725096.png
# Q:\generated_images\1421155409603.jpg
# Q:\generated_images\1421283638825.png
# Q:\generated_images\1421283656857.jpg
# Q:\generated_images\1421327740191.jpg
# Q:\generated_images\1421327740191steameddition.jpg
# Q:\generated_images\1421442112907.jpg
# Q:\generated_images\1421472554967.jpg
# Q:\generated_images\1421556229865.jpg
# Q:\generated_images\1421556546645.png
# Q:\generated_images\1421560697959.png
# Q:\generated_images\1421560759282.jpg
# Q:\generated_images\1421560985989.png
# Q:\generated_images\1421561020394.png
# Q:\generated_images\1421561515071.jpg
# Q:\generated_images\1421561528599.png
# Q:\generated_images\1421561560065.jpg
# Q:\generated_images\1421561566750.png
# Q:\generated_images\1421561609211.jpg
# Q:\generated_images\1421561641585.jpg
# Q:\generated_images\1421561687825.jpg
# Q:\generated_images\1421561795062.png
# Q:\generated_images\1421561821790.png
# Q:\generated_images\1421561832361.png
# Q:\generated_images\1421561918574.jpg
# Q:\generated_images\1421562049982.png
# Q:\generated_images\1421562096518.png
# Q:\generated_images\1421562373790.jpg
# Q:\generated_images\1421562427160.jpg
# Q:\generated_images\1421562610533.jpg
# Q:\generated_images\1421562651919.jpg
# Q:\generated_images\1421562840281.jpg
# Q:\generated_images\1421563069807.jpg
# Q:\generated_images\1421732444669.jpg
# Q:\generated_images\1421803986250.jpg
# Q:\generated_images\1421804934508.jpg
# Q:\generated_images\1421894722507.png
# Q:\generated_images\1421895583667.jpg
# Q:\generated_images\1422181418803.jpg
# Q:\generated_images\1422250498348.jpg
# Q:\generated_images\1422326909673.png
# Q:\generated_images\1422326951668.png
# Q:\generated_images\1422330835913.jpg
# Q:\generated_images\1422330971470.jpg
# Q:\generated_images\1422331026802.jpg
# Q:\generated_images\1422331156595.jpg
# Q:\generated_images\1422331434113.png
# Q:\generated_images\1422331660505.png
# Q:\generated_images\1422563469680.jpg
# Q:\generated_images\1423453798269.jpg
# Q:\generated_images\1423455062411.jpg
# Q:\generated_images\1423455170514.jpg
# Q:\generated_images\1423534007754.jpg
# Q:\generated_images\1423745787677.png
# Q:\generated_images\1423834138543.jpg
# Q:\generated_images\1424134969816.jpg
# Q:\generated_images\1424135207177.jpg
# Q:\generated_images\1424135544678.jpg
# Q:\generated_images\1424135546222.png
# Q:\generated_images\1424137542046.jpg
# Q:\generated_images\1424138021497.png
# Q:\generated_images\1424138285899.jpg
# Q:\generated_images\1424221155251.jpg
# Q:\generated_images\1424223210857.jpg
# Q:\generated_images\1424223374194.jpg
# Q:\generated_images\1424240344251.jpg
# Q:\generated_images\1424241445282.jpg
# Q:\generated_images\1424242149494.jpg
# Q:\generated_images\1424491069189.jpg
# Q:\generated_images\1424491220590.jpg
# Q:\generated_images\1424491335561.jpg
# Q:\generated_images\1424495015172.png
# Q:\generated_images\1424496421764.png
# Q:\generated_images\1424726326679.jpg
# Q:\generated_images\1424726373549.jpg
# Q:\generated_images\1424726437218.jpg
# Q:\generated_images\1424726554085.jpg
# Q:\generated_images\1424726619871.jpg
# Q:\generated_images\1424726621846.jpg
# Q:\generated_images\1424726968143.jpg
# Q:\generated_images\1424732183465.jpg
# Q:\generated_images\1424732220355.jpg
# Q:\generated_images\1424732351676.jpg
# Q:\generated_images\1424732486192.png
# Q:\generated_images\1424732680172.jpg
# Q:\generated_images\1424732797354.png
# Q:\generated_images\1424734263433.jpg
# Q:\generated_images\1424738890799.jpg
# Q:\generated_images\1424746473159.jpg
# Q:\generated_images\1424754428448.jpg
# Q:\generated_images\1425141248192.jpg
# Q:\generated_images\1425141309155.jpg
# Q:\generated_images\1425141335137.jpg
# Q:\generated_images\1425244145777.jpg
# Q:\generated_images\1425246107845.jpg
# Q:\generated_images\1425246306794.jpg
# Q:\generated_images\1425247098191.png
# Q:\generated_images\1425445647527.jpg
# Q:\generated_images\1425448729987.png
# Q:\generated_images\1425521563277.jpg
# Q:\generated_images\1425611244421.jpg
# Q:\generated_images\1425970774262.png
# Q:\generated_images\1425993953689.jpg
# Q:\generated_images\1426015267736.jpg
# Q:\generated_images\1426015637254.jpg
# Q:\generated_images\1426030002055.png
# Q:\generated_images\1426030292899.jpg
# Q:\generated_images\1426030955511.jpg
# Q:\generated_images\1426031970648.jpg
# Q:\generated_images\1426032195249.jpg
# Q:\generated_images\1426032381061.jpg
# Q:\generated_images\1426032598852.jpg
# Q:\generated_images\1426033105310.png
# Q:\generated_images\1426033121089.jpg
# Q:\generated_images\1426033235372.jpg
# Q:\generated_images\1426033467495.jpg
# Q:\generated_images\1426033581066.jpg
# Q:\generated_images\1426033592582.jpg
# Q:\generated_images\1426033619496.jpg
# Q:\generated_images\1426033627343.jpg
# Q:\generated_images\1426033662558.jpg
# Q:\generated_images\1426033683342.jpg
# Q:\generated_images\1426033693948.jpg
# Q:\generated_images\1426033752804.jpg
# Q:\generated_images\1426033807108.jpg
# Q:\generated_images\1426033860175.jpg
# Q:\generated_images\1426033872403.jpg
# Q:\generated_images\1426033971985.jpg
# Q:\generated_images\1426033978528.png
# Q:\generated_images\1426033983393.jpg
# Q:\generated_images\1426033998301.jpg
# Q:\generated_images\1426034008230.jpg
# Q:\generated_images\1426034064645.jpg
# Q:\generated_images\1426034086637.jpg
# Q:\generated_images\1426034114348.png
# Q:\generated_images\1426034139838.jpg
# Q:\generated_images\1426034221883.jpg
# Q:\generated_images\1426034231921.jpg
# Q:\generated_images\1426034240039.jpg
# Q:\generated_images\1426034248883.jpg
# Q:\generated_images\1426106713817.jpg
# Q:\generated_images\1426106917932.jpg
# Q:\generated_images\1426148550169.jpg
# Q:\generated_images\1426176265476.jpg
# Q:\generated_images\1426178608.png
# Q:\generated_images\1426178608058.png
# Q:\generated_images\1426259916391.jpg
# Q:\generated_images\1426309703875.jpg
# Q:\generated_images\1426985826035.jpg
# Q:\generated_images\1426986623127.jpg
# Q:\generated_images\1427056076761.jpg
# Q:\generated_images\1427056204331.jpg
# Q:\generated_images\1427056611470.png
# Q:\generated_images\1427056698575.jpg
# Q:\generated_images\1427153116246.png
# Q:\generated_images\1427774532387.jpg
# Q:\generated_images\1427805951928.png
# Q:\generated_images\1427848785271.jpg
# Q:\generated_images\1427922889246.jpg
# Q:\generated_images\1427923287011.jpg
# Q:\generated_images\1427923821364.jpg
# Q:\generated_images\1427924164957.jpg
# Q:\generated_images\1427936182781.jpg
# Q:\generated_images\1427936283732.jpg
# Q:\generated_images\1427936735970.jpg
# Q:\generated_images\1427936949393.jpg
# Q:\generated_images\1427937118436.jpg
# Q:\generated_images\1427937520318.jpg
# Q:\generated_images\1427939388579.png
# Q:\generated_images\1427939666804.jpg
# Q:\generated_images\1427939856112.jpg
# Q:\generated_images\1427940071806.jpg
# Q:\generated_images\1427942278605.jpg
# Q:\generated_images\1428095816460.jpg
# Q:\generated_images\1428097447682.jpg
# Q:\generated_images\1428098588113.jpg
# Q:\generated_images\1428184012101.jpg
# Q:\generated_images\1428185225929.jpg
# Q:\generated_images\1428299353077.png
# Q:\generated_images\1428299424151.jpg
# Q:\generated_images\1428299424151.png
# Q:\generated_images\1428543794439.jpg
# Q:\generated_images\1428543810463.jpg
# Q:\generated_images\1428543815282.jpg
# Q:\generated_images\1428543826435.jpg
# Q:\generated_images\1428543842864.jpg
# Q:\generated_images\1428543874960.jpg
# Q:\generated_images\1428543890583.jpg
# Q:\generated_images\1428543908435.png
# Q:\generated_images\1428543939573.jpg
# Q:\generated_images\1428544260375.jpg
# Q:\generated_images\1428544529398.jpg
# Q:\generated_images\1428544544614.jpg
# Q:\generated_images\1428545697719.jpg
# Q:\generated_images\1428618695369.png
# Q:\generated_images\1428620795718.jpg
# Q:\generated_images\1428622330927.jpg
# Q:\generated_images\1428625618467.jpg
# Q:\generated_images\1428626210025.jpg
# Q:\generated_images\1428698274588.jpg
# Q:\generated_images\1428809026237.jpg
# Q:\generated_images\1428809059796.jpg
# Q:\generated_images\1428845264533.jpg
# Q:\generated_images\1428845435934.jpg
# Q:\generated_images\1428846635327.png
# Q:\generated_images\1429186899661.jpg
# Q:\generated_images\1429240027554.jpg
# Q:\generated_images\1429240195683.jpg
# Q:\generated_images\1429241368142.jpg
# Q:\generated_images\1429241426520.jpg
# Q:\generated_images\1429241754455.png
# Q:\generated_images\1429243489137.png
# Q:\generated_images\1429243730466.jpg
# Q:\generated_images\1429243917741.jpg
# Q:\generated_images\1429392781040.jpg
# Q:\generated_images\1429393892299.jpg
# Q:\generated_images\1429405345567.jpg
# Q:\generated_images\1429405560044.jpg
# Q:\generated_images\1429485740827.jpg
# Q:\generated_images\1429485960924.jpg
# Q:\generated_images\1429485986891.png
# Q:\generated_images\1429486126787.png
# Q:\generated_images\1429486153902.png
# Q:\generated_images\1429486166657.jpg
# Q:\generated_images\1429486182650.jpg
# Q:\generated_images\1429486198355.jpg
# Q:\generated_images\1429486213316.jpg
# Q:\generated_images\1429486229553.jpg
# Q:\generated_images\1429486249703.jpg
# Q:\generated_images\1429486281768.jpg
# Q:\generated_images\1429486304180.jpg
# Q:\generated_images\1429486321236.png
# Q:\generated_images\1429486329150.jpg
# Q:\generated_images\1429486380879.png
# Q:\generated_images\1429486467925.jpg
# Q:\generated_images\1429486562728.jpg
# Q:\generated_images\1429486682675.png
# Q:\generated_images\1429486758391.jpg
# Q:\generated_images\1429486763420.jpg
# Q:\generated_images\1429486853753.jpg
# Q:\generated_images\1429487477564.png
# Q:\generated_images\1429487973447.jpg
# Q:\generated_images\1429488302513.jpg
# Q:\generated_images\1429488323380.jpg
# Q:\generated_images\1429488532290.jpg
# Q:\generated_images\1429489019067.jpg
# Q:\generated_images\1429489031346.jpg
# Q:\generated_images\1429489094772.jpg
# Q:\generated_images\1429489118273.jpg
# Q:\generated_images\1429490143063.png
# Q:\generated_images\1429503159747.jpg
# Q:\generated_images\1429506271694.jpg
# Q:\generated_images\1429506877609.jpg
# Q:\generated_images\1429507055791.jpg
# Q:\generated_images\1429507142929.jpg
# Q:\generated_images\1429507144132.jpg
# Q:\generated_images\1429507175942.jpg
# Q:\generated_images\1429507192511.jpg
# Q:\generated_images\1429507236450.jpg
# Q:\generated_images\1429507329562.jpg
# Q:\generated_images\1429507367008.jpg
# Q:\generated_images\1429507487494.jpg
# Q:\generated_images\1429507530701.jpg
# Q:\generated_images\1429507599876.jpg
# Q:\generated_images\1429507617259.jpg
# Q:\generated_images\1429507723381.jpg
# Q:\generated_images\1429507764516.jpg
# Q:\generated_images\1429507869189.jpg
# Q:\generated_images\1429508083425.jpg
# Q:\generated_images\1429508275503.jpg
# Q:\generated_images\1429508275503avatar.jpg
# Q:\generated_images\1429508305199.jpg
# Q:\generated_images\1429508347637.jpg
# Q:\generated_images\1429508690903.jpg
# Q:\generated_images\1429508965832.jpg
# Q:\generated_images\1429509013763.jpg
# Q:\generated_images\1429590375613.jpg
# Q:\generated_images\1429590410074.jpg
# Q:\generated_images\1429590421903.jpg
# Q:\generated_images\1429590435393.jpg
# Q:\generated_images\1429590490313.png
# Q:\generated_images\1429590525716.png
# Q:\generated_images\1429590594501.jpg
# Q:\generated_images\1429590743225.jpg
# Q:\generated_images\1429590801166.png
# Q:\generated_images\1429590809500.jpg
# Q:\generated_images\1429590822320.jpg
# Q:\generated_images\1429590884852.jpg
# Q:\generated_images\1429591005319.jpg
# Q:\generated_images\1429591069374.png
# Q:\generated_images\1429591120268.jpg
# Q:\generated_images\1429591166735.png
# Q:\generated_images\1429591296229.jpg
# Q:\generated_images\1429591305851.png
# Q:\generated_images\1430133670739.jpg
# Q:\generated_images\1430136403380.jpg
# Q:\generated_images\1430136690480.jpg
# Q:\generated_images\1430142178437.jpg
# Q:\generated_images\1430143412689.png
# Q:\generated_images\1430144295297.jpg
# Q:\generated_images\1430161232065.jpg
# Q:\generated_images\1430163801148.jpg
# Q:\generated_images\1430164022583.jpg
# Q:\generated_images\1430164072815.png
# Q:\generated_images\1430164331671.jpg
# Q:\generated_images\1430250216649.png
# Q:\generated_images\1430250238259.png
# Q:\generated_images\1430250265792.png
# Q:\generated_images\1430250299181.png
# Q:\generated_images\1430250324057.png
# Q:\generated_images\1430250359580.png
# Q:\generated_images\1430250387298.png
# Q:\generated_images\1430250427572.png
# Q:\generated_images\1430250470199.png
# Q:\generated_images\1430250513484.png
# Q:\generated_images\1430250545052.png
# Q:\generated_images\1430250595491.png
# Q:\generated_images\1430250631627.png
# Q:\generated_images\1430250670114.png
# Q:\generated_images\1430250704904.png
# Q:\generated_images\1430250748066.png
# Q:\generated_images\1430250783092.png
# Q:\generated_images\1430250879226.png
# Q:\generated_images\1430250924419.png
# Q:\generated_images\1430250963688.png
# Q:\generated_images\1430250994194.png
# Q:\generated_images\1430251117961.png
# Q:\generated_images\1430251156439.png
# Q:\generated_images\1430251201988.png
# Q:\generated_images\1430251238915.png
# Q:\generated_images\1430251279217.png
# Q:\generated_images\1430251676110.jpg
# Q:\generated_images\1430601631137.jpg
# Q:\generated_images\1430697273893.png
# Q:\generated_images\1430697491448.png
# Q:\generated_images\1430697863622.jpg
# Q:\generated_images\1430698049850.jpg
# Q:\generated_images\1430698490367.jpg
# Q:\generated_images\1430698534262.png
# Q:\generated_images\1430890392488.jpg
# Q:\generated_images\1430890507195.jpg
# Q:\generated_images\1430890539475.jpg
# Q:\generated_images\1430890599973.png
# Q:\generated_images\1430890766191.jpg
# Q:\generated_images\1430890817627.jpg
# Q:\generated_images\1430891016199.jpg
# Q:\generated_images\1430891018364.jpg
# Q:\generated_images\1430891352162.jpg
# Q:\generated_images\1430891799895.png
# Q:\generated_images\1430973126121.jpg
# Q:\generated_images\1431003207616.jpg
# Q:\generated_images\1431045706506.jpg
# Q:\generated_images\1431127658928.png
# Q:\generated_images\1431128163611.jpg
# Q:\generated_images\1431192652535.jpg
# Q:\generated_images\1431193481369.jpg
# Q:\generated_images\1431218508192.jpg
# Q:\generated_images\1431742914672.jpg
# Q:\generated_images\1431905323755.png
# Q:\generated_images\1431912117933.jpg
# Q:\generated_images\1432152323854.jpg
# Q:\generated_images\1432266135087.png
# Q:\generated_images\1432266904288.png
# Q:\generated_images\1432267290375.jpg
# Q:\generated_images\1432451979989.jpg
# Q:\generated_images\1432452381740.png
# Q:\generated_images\1432560029063.jpg
# Q:\generated_images\1432560761135.png
# Q:\generated_images\1432560849285.jpg
# Q:\generated_images\1432562614294.jpg
# Q:\generated_images\1432562683509.jpg
# Q:\generated_images\1432607258156.jpg
# Q:\generated_images\1432607279494.jpg
# Q:\generated_images\1432608830917.jpg
# Q:\generated_images\1432609912892.jpg
# Q:\generated_images\1432609997248.png
# Q:\generated_images\1432610480347.png
# Q:\generated_images\1432867119642.jpg
# Q:\generated_images\1432960311264.jpg
# Q:\generated_images\1432960476217.png
# Q:\generated_images\1432960514864.jpg
# Q:\generated_images\1432960587657.jpg
# Q:\generated_images\1432960943827.jpg
# Q:\generated_images\1432961080006.png
# Q:\generated_images\1432961320562.jpg
# Q:\generated_images\1432961466409.png
# Q:\generated_images\1432961769644.jpg
# Q:\generated_images\1433017994651.jpg
# Q:\generated_images\1433020410192.jpg
# Q:\generated_images\1433021629518.jpg
# Q:\generated_images\1433021858359.png
# Q:\generated_images\1433224054414.jpg
# Q:\generated_images\1433500979652.jpg
# Q:\generated_images\1433501134048.jpg
# Q:\generated_images\1433777336128.jpg
# Q:\generated_images\1433957979130.jpg
# Q:\generated_images\1433957979130s.jpg
# Q:\generated_images\1433959526644.png
# Q:\generated_images\1434096884930.jpg
# Q:\generated_images\1434378821245.jpg
# Q:\generated_images\1434428394736.jpg
# Q:\generated_images\1435486561704.jpg
# Q:\generated_images\1435489808817.jpg
# Q:\generated_images\1435492712634.png
# Q:\generated_images\1436248805627.jpg
# Q:\generated_images\1436251266508.png
# Q:\generated_images\1436252915632.jpg
# Q:\generated_images\1436307322093.jpg
# Q:\generated_images\1436307479067.png
# Q:\generated_images\1436307578997.jpg
# Q:\generated_images\1436307653305.jpg
# Q:\generated_images\1436307726234.jpg
# Q:\generated_images\1436307873114.jpg
# Q:\generated_images\1436308251417.jpg
# Q:\generated_images\1436308841253.jpg
# Q:\generated_images\1436308981580.jpg
# Q:\generated_images\1436309274659.jpg
# Q:\generated_images\1436309792051.jpg
# Q:\generated_images\1436310329620.jpg
# Q:\generated_images\1436310548853.jpg
# Q:\generated_images\1436311663957.jpg
# Q:\generated_images\1436585084784.jpg
# Q:\generated_images\1436934755342.png
# Q:\generated_images\1436943699934.jpg
# Q:\generated_images\1437431083355.jpg
# Q:\generated_images\1437682640558.jpg
# Q:\generated_images\1437693270710.png
# Q:\generated_images\1437942206333.jpg
# Q:\generated_images\1438036442755.jpg
# Q:\generated_images\1438097571638.jpg
# Q:\generated_images\1438097594576.jpg
# Q:\generated_images\1438097641002.jpg
# Q:\generated_images\1438097676537.jpg
# Q:\generated_images\1438097813868.jpg
# Q:\generated_images\1438097851126.jpg
# Q:\generated_images\1438097933520.jpg
# Q:\generated_images\1438097985189.jpg
# Q:\generated_images\1438098125289.jpg
# Q:\generated_images\1438098502947.jpg
# Q:\generated_images\1438098510827.png
# Q:\generated_images\1438099081487.png
# Q:\generated_images\1438099377475.png
# Q:\generated_images\1438104300588.jpg
# Q:\generated_images\1438104323983.jpg
# Q:\generated_images\1438104607465.png
# Q:\generated_images\1438104890805.jpg
# Q:\generated_images\1438105168030.jpg
# Q:\generated_images\1438111894957.jpg
# Q:\generated_images\1438183513980.jpg
# Q:\generated_images\1438333785805 (1).jpg
# Q:\generated_images\1438333785805.jpg
# Q:\generated_images\1438333972566.jpg
# Q:\generated_images\1438357096547.png
# Q:\generated_images\1438729955099.jpg
# Q:\generated_images\1438830740140.png
# Q:\generated_images\1438882014862.jpg
# Q:\generated_images\1438882036212.jpg
# Q:\generated_images\1438882056799.jpg
# Q:\generated_images\1438882117443.jpg
# Q:\generated_images\1438882251856.jpg
# Q:\generated_images\1438882283970.jpg
# Q:\generated_images\1438882449468.jpg
# Q:\generated_images\1438882970523.jpg
# Q:\generated_images\1438883502992.jpg
# Q:\generated_images\1438883539833.jpg
# Q:\generated_images\1438884048055.jpg
# Q:\generated_images\1439233807922.jpg
# Q:\generated_images\1439236933448.jpg
# Q:\generated_images\1439236959073.jpg
# Q:\generated_images\1439236977647.jpg
# Q:\generated_images\1439236995607.jpg
# Q:\generated_images\1439237013647.jpg
# Q:\generated_images\1439237031810.jpg
# Q:\generated_images\1439237096458.jpg
# Q:\generated_images\1439237104025.jpg
# Q:\generated_images\1439237147349.jpg
# Q:\generated_images\1439237151007.jpg
# Q:\generated_images\1439237202239.jpg
# Q:\generated_images\1439237235668.jpg
# Q:\generated_images\1439237259679.jpg
# Q:\generated_images\1439237271323.jpg
# Q:\generated_images\1439237283115.jpg
# Q:\generated_images\1439237307683.jpg
# Q:\generated_images\1439237311097.jpg
# Q:\generated_images\1439237363459.jpg
# Q:\generated_images\1439237367388.jpg
# Q:\generated_images\1439237395591.jpg
# Q:\generated_images\1439237420662.jpg
# Q:\generated_images\1439237434574.jpg
# Q:\generated_images\1439237445647.jpg
# Q:\generated_images\1439237546891.jpg
# Q:\generated_images\1439237570421.jpg
# Q:\generated_images\1439237794914.jpg
# Q:\generated_images\1439237811528.jpg
# Q:\generated_images\1439237848605.jpg
# Q:\generated_images\1439237913824.jpg
# Q:\generated_images\1439518586896.jpg
# Q:\generated_images\1439520769200.png
# Q:\generated_images\1439520869375.jpg
# Q:\generated_images\1439590620322.jpg
# Q:\generated_images\1439680420635.jpg
# Q:\generated_images\1440023804904.jpg
# Q:\generated_images\1440024553403.jpg
# Q:\generated_images\1440024687366.jpg
# Q:\generated_images\1440024718214.jpg
# Q:\generated_images\1440024812582.jpg
# Q:\generated_images\1440024994254.jpg
# Q:\generated_images\1440025627934.jpg
# Q:\generated_images\1440026261525.jpg
# Q:\generated_images\1440027263094.png
# Q:\generated_images\1440028229897.jpg
# Q:\generated_images\1440029046441.jpg
# Q:\generated_images\1440036001599.png
# Q:\generated_images\1440036041607.jpg
# Q:\generated_images\1440036280871.png
# Q:\generated_images\1440036397137.png
# Q:\generated_images\1440036412773.jpg
# Q:\generated_images\1440036428024.jpg
# Q:\generated_images\1440036446628.jpg
# Q:\generated_images\1440036473022.jpg
# Q:\generated_images\1440036527184.jpg
# Q:\generated_images\1440036807050.png
# Q:\generated_images\1440036860225.jpg
# Q:\generated_images\1440036891787.png
# Q:\generated_images\1440037186697.jpg
# Q:\generated_images\1440037419569.jpg
# Q:\generated_images\1440037455880.jpg
# Q:\generated_images\1440037625567.png
# Q:\generated_images\1440037663200.jpg
# Q:\generated_images\1440037686993.jpg
# Q:\generated_images\1440037823873.png
# Q:\generated_images\1440037992800.png
# Q:\generated_images\1440038192251.jpg
# Q:\generated_images\1440039067026.png
# Q:\generated_images\1440041643312.jpg
# Q:\generated_images\1448815972867.jpg
# Q:\generated_images\1448815983778.png
# Q:\generated_images\1450054824740.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-331-49752bdd65a7> in <module>
#       5 for path in meme_df["path"]:
#       6     ti = TiledImage(image_path=path, tile_shape=(x, y))
# ----> 7     im = ti.make(meme_df)
#       8     f_name = os.path.basename(path)
#       9     dest_path = os.path.join(dest_dir, f_name)
#
# <ipython-input-321-6bc436488207> in make(self, image_dataframe, unique_flag)
#      52                 d_a = np.array(image_dataframe["mean_a"] - color[1])**2
#      53                 d_b = np.array(image_dataframe["mean_b"] - color[2])**2
# ---> 54                 dist = d_L + d_a + d_b
#      55                 distance_matrix.append(dist)
#      56
#
# KeyboardInterrupt:

# %%
A = np.array([
    [1,2,3],
    [-1,3,4],
    [5,0,5],
    [8,9,-2]
])

# %%
A
# Out:
# array([[100,   2,   3],
#        [100,   3,   4],
#        [  5, 100,   5],
#        [  8,   9, 100]])

# %%
n = np.argmin(A)
n
# Out:
# 0

# %%
h, w = A.shape
h, w
# Out:
# (4, 3)

# %%
i, j = n//w, n%w
i, j
# Out:
# (0, 0)

# %%
A[i, j] = 100

# %%
dist_matrix.shape
# Out:
# (273, 1653)
